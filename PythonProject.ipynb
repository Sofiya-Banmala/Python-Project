# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# !pip install datasets
from datasets import load_dataset
data = load_dataset('lukebarousse/data_jobs')
df =data['train'].to_pandas()
df.head()
# Out:
# ...
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location      job_posted_date  \
# ...

# %%
Aus_job = df[df.job_country == 'Australia'] # filter to australia
Aus_skills = Aus_job[Aus_job.salary_year_avg.notna()] # removing null

# %%
# Median_Yearly_Salary = df['salary_year_avg'].median()
# Median_Salary_Hourly = df['salary_hour_avg'].median()

# %%
# df['salary_year_avg'] = df['salary_year_avg'].fillna(Median_Yearly_Salary) # filled all null cases and Nan with median salary in our dataset
# df['salary_hour_avg'] = df['salary_hour_avg'].fillna(Median_Salary_Hourly) # filled all null cases and Nan with median salary in our dataset

# %%
df.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location      job_posted_date  \
# ...

# %%
df.loc[:, 'salary_year_avg': 'salary_hour_avg'] # : gives all records for salary_year_avg & salary_hour_avg
# Out:
#         salary_year_avg  salary_hour_avg
# 0                   NaN              NaN
# 1                   NaN              NaN
# 2                   NaN              NaN
# 3                   NaN              NaN
# 4                   NaN              NaN
# ...                 ...              ...
# 785736              NaN              NaN
# 785737              NaN              NaN
# 785738              NaN              NaN
# 785739              NaN              NaN
# 785740              NaN              NaN
#
# [785741 rows x 2 columns]

# %%
df_unique = df.copy()

df_unique = df_unique.drop_duplicates() # drop_duplicates function will drop all duplicate records

# %%
len(df)
# Out:
# 785741

# %%
print('Total records:',len(df))
print('Unique records:',len(df_unique))
print('Duplicates :',len(df)-len(df_unique))
# Out:
# Total records: 785741
# Unique records: 785640
# Duplicates : 101

# %%
df_unique = df_unique.drop_duplicates(subset = ['job_title','company_name'])

# %%
print('Total records:',len(df))
print('Unique records:',len(df_unique))
print('Duplicates :',len(df)-len(df_unique))
# Out:
# Total records: 785741
# Unique records: 508042
# Duplicates : 277699

# %%
df_salary_job_contry = df.pivot_table(values='salary_year_avg', index= 'job_country', columns='job_title_short', aggfunc='median',fill_value=0)

# %%
df_salary_job_contry.head()
# Out:
# job_title_short  Business Analyst  Cloud Engineer  Data Analyst  \
# job_country
# Albania                       0.0             0.0      49950.00
# Algeria                       0.0             0.0      44100.00
# Argentina                 71100.0        197500.0      92771.75
# Armenia                       0.0             0.0     100500.00
# Australia                 70000.0        110000.0     109500.00
#
# job_title_short  Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_country
# Albania                    0.0        69981.25                        0.0
# Algeria                45000.0            0.00                        0.0
# Argentina              96773.0        71000.00                   101029.0
# Armenia                48750.0            0.00                    87021.0
# Australia             106712.5       139216.00                   101029.0
#
# job_title_short  Senior Data Analyst  Senior Data Engineer  \
# job_country
# ...

# %%
df_salary_job_contry.index
# Out:
# Index(['Albania', 'Algeria', 'Argentina', 'Armenia', 'Australia', 'Austria',
#        'Azerbaijan', 'Bahamas', 'Bangladesh', 'Belarus',
#        ...
#        'Uganda', 'Ukraine', 'United Arab Emirates', 'United Kingdom',
#        'United States', 'Uruguay', 'Uzbekistan', 'Vietnam', 'Zambia',
#        'Zimbabwe'],
#       dtype='object', name='job_country', length=108)

# %%
top_countries = df['job_country'].value_counts().sort_values(ascending = False).head(10) # top 10 countries by count

# record count of job country and then sort by descending and top 10 countries with most job

# %%
top10_countries = df['job_country'].value_counts().sort_values(ascending = False).head(10).index # top 10 countries by count

# %%
top_countries
# Out:
# job_country
# United States     206292
# India              51088
# United Kingdom     40375
# France             39922
# Germany            27694
# Spain              25100
# Singapore          23696
# Sudan              21781
# Netherlands        20631
# Italy              17013
# Name: count, dtype: int64

# %%
top10_contries= df_salary_job_contry.loc[top10_countries]

# %%
job_titles = ['Data Analyst','Data Engineer','Data Scientist']

# %%
df_job_country_salary = top10_contries[job_titles]

# %%
ax = df_job_country_salary.plot(kind = 'bar', figsize=(12,6))
ax.legend(loc='upper left')
plt.title("Job Posting across top 10 Countries")
plt.ylabel("Median Salary")
plt.tight_layout()
plt.show()

# Insights -- India and Germany has highest median salary for Data Engineer job titles, where as Netherlands has highest median salary for Data Scientist
# The insights tells us that candidate needs to switch there jobs in respective countries to earn more income.

# %%
df.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location      job_posted_date  \
# ...

# %%
df_exploded = df.explode('job_skills')

# %%
df_exploded.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location      job_posted_date  \
# ...

# %%
import ast

df_clean = df[df['job_skills'].notna()] # remove null or Nan or none case
df_clean['job_skills'] = df_clean['job_skills'].apply(ast.literal_eval) # convert to list
# Out:
# <ipython-input-121-42b83d94627c>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['job_skills'] = df_clean['job_skills'].apply(ast.literal_eval) # convert to list

# %%
df_exploded = df_clean.explode('job_skills') # explode

# %%
df_exploded.head()
# Out:
#   job_title_short     job_title                  job_location  \
# 1    Data Analyst  Data Analyst  Guadalajara, Jalisco, Mexico
# 1    Data Analyst  Data Analyst  Guadalajara, Jalisco, Mexico
# 1    Data Analyst  Data Analyst  Guadalajara, Jalisco, Mexico
# 1    Data Analyst  Data Analyst  Guadalajara, Jalisco, Mexico
# 1    Data Analyst  Data Analyst  Guadalajara, Jalisco, Mexico
#
#             job_via job_schedule_type  job_work_from_home search_location  \
# 1  via BeBee México         Full-time               False          Mexico
# 1  via BeBee México         Full-time               False          Mexico
# 1  via BeBee México         Full-time               False          Mexico
# 1  via BeBee México         Full-time               False          Mexico
# 1  via BeBee México         Full-time               False          Mexico
#
#        job_posted_date  job_no_degree_mention  job_health_insurance  \
# 1  2023-01-14 13:18:07                  False                 False
# ...

# %%
df_exploded['job_skills'].value_counts().sort_values(ascending = False).head(10)
# Out:
# job_skills
# sql         384849
# python      380909
# aws         145381
# azure       132527
# r           130892
# tableau     127213
# excel       127018
# spark       114609
# power bi     98147
# java         85612
# Name: count, dtype: int64

# %%
df_exploded['job_skills'].value_counts().sort_values(ascending = False).head(10).plot(kind = 'barh')
# Out:
# <Axes: ylabel='job_skills'>

# %%
skill_counts = df_exploded.groupby(['job_title_short','job_skills']).size()

# %%
skill_counts
# Out:
# job_title_short    job_skills
# Business Analyst   airflow        318
#                    airtable        17
#                    alteryx       1078
#                    angular         87
#                    ansible        120
#                                  ...
# Software Engineer  wrike            4
#                    wsl             13
#                    xamarin         35
#                    yarn           145
#                    zoom           229
# Length: 2256, dtype: int64

# %%
df_skill_counts = skill_counts.reset_index(name = 'skill_counts')

# %%
df_skill_counts = df_skill_counts.sort_values(by=  'skill_counts',ascending=False)

# %%
df_skill_counts
# Out:
#         job_title_short job_skills  skill_counts
# 0      Business Analyst    airflow           318
# 1      Business Analyst   airtable            17
# 2      Business Analyst    alteryx          1078
# 3      Business Analyst    angular            87
# 4      Business Analyst    ansible           120
# ...                 ...        ...           ...
# 2251  Software Engineer      wrike             4
# 2252  Software Engineer        wsl            13
# 2253  Software Engineer    xamarin            35
# 2254  Software Engineer       yarn           145
# 2255  Software Engineer       zoom           229
#
# [2256 rows x 3 columns]

# %%
job_titles='Data Analyst'
top_skills = 10
df_DA_skillset = df_skill_counts[df_skill_counts['job_title_short'] == job_titles].head(top_skills)

# %%
df_DA_skillset.plot(kind = 'barh', x='job_skills', y='skill_counts')
# Out:
# <Axes: ylabel='job_skills'>

# %%
job_titles='Data Engineer'
top_skills = 10
df_DE_skillset = df_skill_counts[df_skill_counts['job_title_short'] == job_titles].head(top_skills)
df_DE_skillset.plot(kind = 'barh', x='job_skills', y='skill_counts')
# Out:
# <Axes: ylabel='job_skills'>

# %%
job_titles='Data Scientist'
top_skills = 10
df_DS_skillset = df_skill_counts[df_skill_counts['job_title_short'] == job_titles].head(top_skills)
df_DS_skillset.plot(kind = 'barh', x='job_skills', y='skill_counts')
# Out:
# <Axes: ylabel='job_skills'>

# %%
fig,ax = plt.subplots(1,3)
df_DA_skillset.plot(kind = 'barh', x='job_skills', y='skill_counts',ax = ax[0])
df_DE_skillset.plot(kind = 'barh', x='job_skills', y='skill_counts',ax = ax[1])
df_DS_skillset.plot(kind = 'barh', x='job_skills', y='skill_counts', ax = ax[2])
# Out:
# <Axes: ylabel='job_skills'>

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 3, figsize=(18, 8), constrained_layout=True)

# Plotting with customizations
df_DA_skillset.plot(kind='barh', x='job_skills', y='skill_counts', ax=ax[0], color='skyblue', legend=False)
ax[0].set_title('Data Analyst Skills')
ax[0].invert_yaxis()  # Highest at top
ax[0].set_xlabel('Count')
ax[0].set_ylabel('Skills')

df_DE_skillset.plot(kind='barh', x='job_skills', y='skill_counts', ax=ax[1], color='lightgreen', legend=False)
ax[1].set_title('Data Engineer Skills')
ax[1].invert_yaxis()
ax[1].set_xlabel('Count')
ax[1].set_ylabel('')

df_DS_skillset.plot(kind='barh', x='job_skills', y='skill_counts', ax=ax[2], color='salmon', legend=False)
ax[2].set_title('Data Scientist Skills')
ax[2].invert_yaxis()
ax[2].set_xlabel('Count')
ax[2].set_ylabel('')

# Optional: Adjust font size if labels are long
for a in ax:
    a.tick_params(axis='y', labelsize=9)

plt.suptitle("Top Skills in Data Roles", fontsize=16)
plt.show()

# %%
skills_stats = df_exploded.groupby('job_skills').agg(skill_count = ('job_skills','count'),median_salary=('salary_year_avg','median'))
skills_Statistics = skills_stats.sort_values(by='skill_count',ascending=False).head(10)
# skill count = column name , median_salary = column name

# %%
# Out:
#                    skill_count  median_salary
# job_skills
# ['excel']                13238   77446.000000
# ['sql']                  11732   99589.750000
# ['python']                8509  127500.000000
# ['python', 'sql']         4753  143500.000000
# ['sql', 'excel']          4399   90000.000000
# ['sql', 'python']         4340  115653.984375
# ['sap']                   3829  105000.000000
# ['go']                    3429  108415.500000
# ['python', 'r']           3103  136656.000000
# ['flow']                  2890   95000.000000

# %%
skills_Statistics.plot(kind= 'scatter', x='skill_count', y='median_salary')
plt.xlabel("Job Posting")
plt.ylabel("Median Salary")

for i, text in enumerate(skills_Statistics.index):
  plt.text(skills_Statistics['skill_count'].iloc[i],skills_Statistics['median_salary'].iloc[i],text)
  plt.tight_layout()
